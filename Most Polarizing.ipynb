# %%
# Import all dependencies
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
from config import db_password

# %%
# Create engine to connect and store in SQL database
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Twitter_Project"
engine = create_engine(db_string)
session = Session(engine)

# %%
pol_df= pd.read_sql_query('''SELECT * FROM "polarities";''', engine)
pol_df.head()
# Out:
#                                      user_name                user_location  \
# 0                                     MyNewsNE                        Assam
# 1                           Ann-Maree O’Connor    Adelaide, South Australia
# 2                             Rajesh Tadepalli             Hyderabad, India
# 3  AKisASocialisolationist wash yer damn hands  The Great Pacific Northwest
# 4                           Dr. Joseph Santoro         Washington, DC 20009
#
#   user_verified                date  \
# 0         False 2020-08-18 12:55:00
# 1         False 2020-08-18 12:45:00
# 2         False 2020-08-18 12:34:00
# 3         False 2020-08-18 12:30:00
# 4         False 2020-08-18 12:15:00
#
#                                                 text          hashtags  \
# 0  australia manufacture covid vaccine give citiz...  ['CovidVaccine']
# 1        passes leadership country voucher something              None
# 2                                                                 None
# 3  well qualify would anyone party vaccine rushed...  ['CovidVaccine']
# 4  countries without ability make locally forced ...      ['Vaccines']
#
#   is_retweet                                          tokenized  subjectivity  \
# 0      False  {australia,manufactur,covid,vaccin,give,citize...           0.8
# 1      False           {pass,leadership,countri,voucher,someth}           0.0
# 2      False                                                 {}           0.0
# 3      False  {well,qualifi,would,anyon,parti,vaccin,rush,mi...           0.6
# 4      False  {countri,without,abil,make,local,forc,reli,oth...           0.2
#
#    polarity     label
# 0       0.4  Positive
# 1       0.0   Neutral
# 2       0.0   Neutral
# 3      -0.1  Negative
# 4      -0.3  Negative

# %%
pos_df= pol_df.sort_values(["polarity"], ascending=True)
pos_df.head()
# Out:
#                 user_name                 user_location user_verified  \
# 206577              🌷H-K🌷                           USA         False
# 416921            Tomasso                        London         false
# 131508     missy kupillas  In a Galaxy far, far away...         False
# 26584   Nicolas D Navarro              Pensilvania, USA         False
# 427779       Rahim Bha_kt                         India         false
#
#                       date                                               text  \
# 206577 2021-07-24 17:00:19  proof government trying kill horrific findings...
# 416921 2021-10-03 23:18:42  pathetic delays covaxin approval youre protect...
# 131508 2021-03-24 20:01:38             nasty sore injection days side effects
# 26584  2020-12-28 17:37:57  worst thing could happened government charge d...
# 427779 2021-11-03 13:20:36     dont watch movie worst amar appeal rename patn
#
#                        hashtags is_retweet  \
# 206577         ['CovidVaccine']      False
# 416921                     None      False
# 131508                     None      False
# 26584          ['CovidVaccine']      False
# 427779  ['sushanthsinghrajput']      False
#
#                                                 tokenized  subjectivity  \
# 206577   {proof,govern,tri,kill,horrif,find,blood,vaccin}           1.0
# 416921  {pathet,delay,covaxin,approv,your,protect,pfiz...           1.0
# 131508                {nasti,sore,inject,day,side,effect}           1.0
# 26584   {worst,thing,could,happen,govern,charg,distribut}           1.0
# 427779     {dont,watch,movi,worst,amar,appeal,renam,patn}           1.0
#
#         polarity     label
# 206577      -1.0  Negative
# 416921      -1.0  Negative
# 131508      -1.0  Negative
# 26584       -1.0  Negative
# 427779      -1.0  Negative

# %%
neg_df= pol_df.sort_values(["polarity"], ascending=False)
neg_df.head()
# Out:
#                  user_name   user_location user_verified                date  \
# 340493      𝓐𝓶𝓳𝓪𝓭 𝓥𝓮𝓱𝓷𝓲𝔀𝓪𝓵   ملتان / وہاڑی         false 2021-05-30 06:05:14
# 97122                  Kay  United Kingdom         False 2021-02-14 19:20:26
# 284109  Michelle Elizabeth     Houston, TX         false 2021-02-10 20:38:18
# 360632        angsumandeka     Seattle, WA         false 2021-06-30 02:37:55
# 118675     Kevin Lindamood       Baltimore         False 2021-02-19 15:48:40
#
#                                                      text  \
# 340493                          done excellent arangments
# 97122             perfect valentines viewing perhaps hope
# 284109  best performing stock investments gain since t...
# 360632                                        superb news
# 118675  always informative work front door screening s...
#
#                                                  hashtags is_retweet  \
# 340493                          ['vaccinated', 'Sinovac']      False
# 97122                                    ['COVIDVaccine']      False
# 284109                                               None      False
# 360632  ['COVAXIN', 'covaxine', 'VaxToWin', 'vaxxedtot...      False
# 118675                                               None      False
#
#                                                 tokenized  subjectivity  \
# 340493                                 {done,excel,arang}           1.0
# 97122                 {perfect,valentin,view,perhap,hope}           1.0
# 284109  {best,perform,stock,invest,gain,sinc,took,posi...           0.3
# 360632                                      {superb,news}           1.0
# 118675  {alway,inform,work,front,door,screen,shift,tod...           1.0
#
#         polarity     label
# 340493       1.0  Positive
# 97122        1.0  Positive
# 284109       1.0  Positive
# 360632       1.0  Positive
# 118675       1.0  Positive

# %%
neu_df= pol_df.loc[pol_df['polarity'] ==0]
neu_df.head(15)
# Out:
#                      user_name              user_location user_verified  \
# 1           Ann-Maree O’Connor  Adelaide, South Australia         False
# 2             Rajesh Tadepalli           Hyderabad, India         False
# 5                     VUMC OAP              Nashville, TN         False
# 6                    HrNxt.com                      India         False
# 7           Mohammadali Naseri                     TEHRAN         False
# 10                moneycontrol                     Mumbai          True
# 11          Ravi Prakash Singh                 Ponda, Goa         False
# 12               Duvar English          İstanbul, Türkiye         False
# 13                neonatal2k20           Hyderabad, India         False
# 16         JPIMedia Design Hub          Sheffield & Leeds         False
# 18               Oneindia News                      India          True
# 19          Yash Tiwari Speaks                      India         False
# 20  World School of Bangladesh                 Bangladesh         False
# 21                      Factly       Hyderabad, Telangana          True
# 22  World School of Bangladesh                 Bangladesh         False
#
#                   date                                               text  \
# 1  2020-08-18 12:45:00        passes leadership country voucher something
# 2  2020-08-18 12:34:00
# 5  2020-08-18 11:57:00                     zooms charts week hear episode
# 6  2020-08-18 11:12:00  biocon executive chairperson kiran mazumdar sh...
# 7  2020-08-18 11:04:00
# 10 2020-08-18 10:38:00  looking raise billion around crore covid vacci...
# 11 2020-08-18 10:36:00                             global vaccine tracker
# 12 2020-08-18 09:49:00  coronavirus updates american businessman turki...
# 13 2020-08-18 09:13:00                                        attend also
# 16 2020-08-18 08:00:00            vaccinate world source design mark hall
# 18 2020-08-18 07:30:00      study shows seroprevalence antibodies samples
# 19 2020-08-18 07:26:00  featured today awarded prestigious india book ...
# 20 2020-08-18 07:04:00   covid vocabulary english incubation period click
# 21 2020-08-18 05:55:00      candidates begin trials phase clinical trials
# 22 2020-08-18 05:49:00          covid vocabulary english infectious click
#
#                                              hashtags is_retweet  \
# 1                                                None      False
# 2                                                None      False
# 5   ['DNA', 'vaccines', 'pandemic', 'COVID19', 'Co...      False
# 6                                                None      False
# 7   ['Covid19Millionares', 'covid19', 'corona', 'C...      False
# 10                                               None      False
# 11                       ['vaccines', 'CovidVaccine']      False
# 12                                               None      False
# 13  ['webinar', 'pediatrics', 'neonatology', 'prim...      False
# 16  ['vacine', 'vaccinate', 'coronavirus', 'covidv...      False
# 18  ['covid19', 'Pune', 'COVID19India', 'CovidVacc...      False
# 19                                               None      False
# 20                                        ['COVID19']      False
# 21                                   ['CovidVaccine']      False
# 22                           ['COVID19', 'COVID__19']      False
#
#                                             tokenized  subjectivity  polarity  \
# 1            {pass,leadership,countri,voucher,someth}           0.0       0.0
# 2                                                  {}           0.0       0.0
# 5                       {zoom,chart,week,hear,episod}           0.0       0.0
# 6   {biocon,execut,chairperson,kiran,mazumdar,shaw...           0.0       0.0
# 7                                                  {}           0.0       0.0
# 10  {look,rais,billion,around,crore,covid,vaccin,d...           0.0       0.0
# 11                            {global,vaccin,tracker}           0.0       0.0
# 12  {coronaviru,updat,american,businessman,turkish...           0.0       0.0
# 13                                      {attend,also}           0.0       0.0
# 16              {vaccin,world,sourc,design,mark,hall}           0.0       0.0
# 18             {studi,show,seropreval,antibodi,sampl}           0.0       0.0
# 19  {featur,today,award,prestigi,india,book,record...           0.0       0.0
# 20      {covid,vocabulari,english,incub,period,click}           0.0       0.0
# 21            {candid,begin,trial,phase,clinic,trial}           0.0       0.0
# 22           {covid,vocabulari,english,infecti,click}           0.0       0.0
#
#       label
# 1   Neutral
# 2   Neutral
# 5   Neutral
# 6   Neutral
# 7   Neutral
# 10  Neutral
# 11  Neutral
# 12  Neutral
# 13  Neutral
# 16  Neutral
# 18  Neutral
# 19  Neutral
# 20  Neutral
# 21  Neutral
# 22  Neutral
