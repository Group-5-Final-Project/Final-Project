# %%
# Import all dependencies
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
from config import db_password
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# Create engine to connect and store in SQL database
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/tweet_project"
engine = create_engine(db_string)
session = Session(engine)

# %%
pol_df= pd.read_sql_query('''SELECT * FROM "polarities";''', engine)
pol_df.head()
# Out:
#    index                                    user_name  \
# 0      0                                     MyNewsNE
# 1      1                           Ann-Maree O’Connor
# 2      2                             Rajesh Tadepalli
# 3      3  AKisASocialisolationist wash yer damn hands
# 4      4                           Dr. Joseph Santoro
#
#                  user_location user_verified                date  \
# 0                        Assam         False 2020-08-18 12:55:00
# 1    Adelaide, South Australia         False 2020-08-18 12:45:00
# 2             Hyderabad, India         False 2020-08-18 12:34:00
# 3  The Great Pacific Northwest         False 2020-08-18 12:30:00
# 4         Washington, DC 20009         False 2020-08-18 12:15:00
#
#                                                 text          hashtags  \
# 0  australia manufacture covid vaccine give citiz...  ['CovidVaccine']
# 1        passes leadership country voucher something              None
# ...

# %%
pos_df= pol_df.sort_values(["polarity"], ascending=True)
pos_df.head()
# Out:
#          index           user_name       user_location user_verified  \
# 6779      6750  Lascar Electronics  Salisbury, England         False
# 435181  435164          Mayascribe       Suburbia, USA         false
# 26584    26558   Nicolas D Navarro    Pensilvania, USA         False
# 315890  315810           Nikhil K.       Mumbai, India         false
# 173729  173674           Ryan inNC       Charlotte, NC         False
#
#                       date                                               text  \
# 6779   2020-10-16 10:20:45  intensity coronavirus pandemic devastating eff...
# 435181 2021-11-17 19:16:36  shocking england journal medicine study vaccin...
# 26584  2020-12-28 17:37:57  worst thing could happened government charge d...
# 315890 2021-04-07 07:32:35  vicious people like treating vaccines like der...
# 173729 2021-06-21 15:59:31       eric clapton talks awful reactions receiving
#
#                                                  hashtags is_retweet  \
# ...

# %%
neg_df= pol_df.sort_values(["polarity"], ascending=False)
neg_df.head()
# Out:
#          index                    user_name         user_location  \
# 158872  158846            AgilityWithAmanda       Barrie, Ontario
# 284356  284236  Sue Reeve ♥️🧡💛💚💙💜🇪🇺🏳️‍🌈🕊️🕷️     Glasgow environs.
# 358233  358218                       Jordan          Winnipeg, MB
# 325480  325432                      Robt2d2  Livingston, Scotland
# 44449    44415               Ajmera Fashion          Surat, India
#
#        user_verified                date  \
# 158872         False 2021-04-22 22:06:37
# 284356         false 2021-02-12 17:19:10
# 358233         false 2021-06-22 18:41:48
# 325480         false 2021-04-20 12:13:09
# 44449          False 2021-01-09 09:39:19
#
#                                                      text  \
# 158872  well official today received dose pfizer covid...
# 284356  excellent beginning think might away despite list
# 358233  fully vaccinated participated movie covid shot...
# 325480         today vacation science best thank everyone
# ...

# %%
neu_df= pol_df.loc[pol_df['polarity'] ==0]
neu_df.head(15)
# Out:
#     index                   user_name              user_location  \
# 1       1          Ann-Maree O’Connor  Adelaide, South Australia
# 2       2            Rajesh Tadepalli           Hyderabad, India
# 5       5                    VUMC OAP              Nashville, TN
# 6       6                   HrNxt.com                      India
# 7       7          Mohammadali Naseri                     TEHRAN
# 10     10                moneycontrol                     Mumbai
# 11     11          Ravi Prakash Singh                 Ponda, Goa
# 12     12               Duvar English          İstanbul, Türkiye
# 13     13                neonatal2k20           Hyderabad, India
# 16     16         JPIMedia Design Hub          Sheffield & Leeds
# 18     18               Oneindia News                      India
# 19     19          Yash Tiwari Speaks                      India
# 20     20  World School of Bangladesh                 Bangladesh
# ...
